# %%
from IPython.display import HTML

datapath = "/home/noud333/bachelorproject/data"

# %%
HTML(filename=f'{datapath}/pandexo/V1298TauB_MIRI.html')
# Out:
# <!DOCTYPE html>
# <html lang="en">
#     <head>
#         <meta charset="utf-8">
#         <title>Bokeh Plot</title>
#
# <link rel="stylesheet" href="https://cdn.pydata.org/bokeh/release/bokeh-0.12.6.min.css" type="text/css" />
#
# <script type="text/javascript" src="https://cdn.pydata.org/bokeh/release/bokeh-0.12.6.min.js"></script>
# <script type="text/javascript">
#     Bokeh.set_log_level("info");
# </script>
#         <style>
#           html {
#             width: 100%;
#             height: 100%;
#           }
#           body {
#             width: 90%;
#             height: 100%;
#             margin: auto;
#           }
#         </style>
#     </head>
#     <body>
#
#         <div class="bk-root">
#             <div class="bk-plotdiv" id="153ed1c1-726a-42b6-b6fd-64bf510bd74e"></div>
#         </div>
#
#         <script type="text/javascript">
#             (function() {
#           var fn = function() {
#             Bokeh.safely(function() {
# ...

# %%
HTML(filename=f'{datapath}/pandexo/V1298TauB_NIRISS.html')
# Out:
# <!DOCTYPE html>
# <html lang="en">
#     <head>
#         <meta charset="utf-8">
#         <title>Bokeh Plot</title>
#
# <link rel="stylesheet" href="https://cdn.pydata.org/bokeh/release/bokeh-0.12.6.min.css" type="text/css" />
#
# <script type="text/javascript" src="https://cdn.pydata.org/bokeh/release/bokeh-0.12.6.min.js"></script>
# <script type="text/javascript">
#     Bokeh.set_log_level("info");
# </script>
#         <style>
#           html {
#             width: 100%;
#             height: 100%;
#           }
#           body {
#             width: 90%;
#             height: 100%;
#             margin: auto;
#           }
#         </style>
#     </head>
#     <body>
#
#         <div class="bk-root">
#             <div class="bk-plotdiv" id="c3f8bc44-9ac7-400d-a9e1-b1e933ba35c8"></div>
#         </div>
#
#         <script type="text/javascript">
#             (function() {
#           var fn = function() {
#             Bokeh.safely(function() {
# ...

# %% [markdown]
# The major error bars here are due detector gaps at those wavelengths. [Check the first table](https://www.cosmos.esa.int/web/jwst-nirspec/bots), [other source](https://jwst-docs.stsci.edu/jwst-near-infrared-spectrograph/nirspec-operations/nirspec-bots-operations/nirspec-bots-wavelength-ranges-and-gaps)

# %%
HTML(filename=f'{datapath}/pandexo/V1298TauB_NIRSPEC_H.html')
# Out:
# <!DOCTYPE html>
# <html lang="en">
#     <head>
#         <meta charset="utf-8">
#         <title>Bokeh Plot</title>
#
# <link rel="stylesheet" href="https://cdn.pydata.org/bokeh/release/bokeh-0.12.6.min.css" type="text/css" />
#
# <script type="text/javascript" src="https://cdn.pydata.org/bokeh/release/bokeh-0.12.6.min.js"></script>
# <script type="text/javascript">
#     Bokeh.set_log_level("info");
# </script>
#         <style>
#           html {
#             width: 100%;
#             height: 100%;
#           }
#           body {
#             width: 90%;
#             height: 100%;
#             margin: auto;
#           }
#         </style>
#     </head>
#     <body>
#
#         <div class="bk-root">
#             <div class="bk-plotdiv" id="12cadf07-49e7-48d0-b026-59124e5fc6ac"></div>
#         </div>
#
#         <script type="text/javascript">
#             (function() {
#           var fn = function() {
#             Bokeh.safely(function() {
# ...

# %%
HTML(filename=f'{datapath}/pandexo/V1298TauB_NIRSPEC_M.html')
# Out:
# <!DOCTYPE html>
# <html lang="en">
#     <head>
#         <meta charset="utf-8">
#         <title>Bokeh Plot</title>
#
# <link rel="stylesheet" href="https://cdn.pydata.org/bokeh/release/bokeh-0.12.6.min.css" type="text/css" />
#
# <script type="text/javascript" src="https://cdn.pydata.org/bokeh/release/bokeh-0.12.6.min.js"></script>
# <script type="text/javascript">
#     Bokeh.set_log_level("info");
# </script>
#         <style>
#           html {
#             width: 100%;
#             height: 100%;
#           }
#           body {
#             width: 90%;
#             height: 100%;
#             margin: auto;
#           }
#         </style>
#     </head>
#     <body>
#
#         <div class="bk-root">
#             <div class="bk-plotdiv" id="40ea56c9-084b-448d-921a-acb5b5f34935"></div>
#         </div>
#
#         <script type="text/javascript">
#             (function() {
#           var fn = function() {
#             Bokeh.safely(function() {
# ...

# %%
HTML(filename=f'{datapath}/pandexo/V1298TauB_MIRI.html')
# Out:
# <!DOCTYPE html>
# <html lang="en">
#     <head>
#         <meta charset="utf-8">
#         <title>Bokeh Plot</title>
#
# <link rel="stylesheet" href="https://cdn.pydata.org/bokeh/release/bokeh-0.12.6.min.css" type="text/css" />
#
# <script type="text/javascript" src="https://cdn.pydata.org/bokeh/release/bokeh-0.12.6.min.js"></script>
# <script type="text/javascript">
#     Bokeh.set_log_level("info");
# </script>
#         <style>
#           html {
#             width: 100%;
#             height: 100%;
#           }
#           body {
#             width: 90%;
#             height: 100%;
#             margin: auto;
#           }
#         </style>
#     </head>
#     <body>
#
#         <div class="bk-root">
#             <div class="bk-plotdiv" id="153ed1c1-726a-42b6-b6fd-64bf510bd74e"></div>
#         </div>
#
#         <script type="text/javascript">
#             (function() {
#           var fn = function() {
#             Bokeh.safely(function() {
# ...

# %%
HTML(filename=f'{datapath}/pandexo/V1298TauB_NIRSPECM_667K.html')
# Out:
# <!DOCTYPE html>
# <html lang="en">
#     <head>
#         <meta charset="utf-8">
#         <title>Bokeh Plot</title>
#
# <link rel="stylesheet" href="https://cdn.pydata.org/bokeh/release/bokeh-0.12.6.min.css" type="text/css" />
#
# <script type="text/javascript" src="https://cdn.pydata.org/bokeh/release/bokeh-0.12.6.min.js"></script>
# <script type="text/javascript">
#     Bokeh.set_log_level("info");
# </script>
#         <style>
#           html {
#             width: 100%;
#             height: 100%;
#           }
#           body {
#             width: 90%;
#             height: 100%;
#             margin: auto;
#           }
#         </style>
#     </head>
#     <body>
#
#         <div class="bk-root">
#             <div class="bk-plotdiv" id="13e85254-be9c-4131-a62e-7361caa0999f"></div>
#         </div>
#
#         <script type="text/javascript">
#             (function() {
#           var fn = function() {
#             Bokeh.safely(function() {
# ...

# %%
HTML(filename=f'{datapath}/pandexo/V1298TauB_NIRSPECM_750K.html')
# Out:
# <!DOCTYPE html>
# <html lang="en">
#     <head>
#         <meta charset="utf-8">
#         <title>Bokeh Plot</title>
#
# <link rel="stylesheet" href="https://cdn.pydata.org/bokeh/release/bokeh-0.12.6.min.css" type="text/css" />
#
# <script type="text/javascript" src="https://cdn.pydata.org/bokeh/release/bokeh-0.12.6.min.js"></script>
# <script type="text/javascript">
#     Bokeh.set_log_level("info");
# </script>
#         <style>
#           html {
#             width: 100%;
#             height: 100%;
#           }
#           body {
#             width: 90%;
#             height: 100%;
#             margin: auto;
#           }
#         </style>
#     </head>
#     <body>
#
#         <div class="bk-root">
#             <div class="bk-plotdiv" id="54b2db02-9679-4f02-96a0-02b67d865f86"></div>
#         </div>
#
#         <script type="text/javascript">
#             (function() {
#           var fn = function() {
#             Bokeh.safely(function() {
# ...

# %%
HTML(filename=f'{datapath}/pandexo/V1298TauB_NIRSPECM_875K.html')
# Out:
# <!DOCTYPE html>
# <html lang="en">
#     <head>
#         <meta charset="utf-8">
#         <title>Bokeh Plot</title>
#
# <link rel="stylesheet" href="https://cdn.pydata.org/bokeh/release/bokeh-0.12.6.min.css" type="text/css" />
#
# <script type="text/javascript" src="https://cdn.pydata.org/bokeh/release/bokeh-0.12.6.min.js"></script>
# <script type="text/javascript">
#     Bokeh.set_log_level("info");
# </script>
#         <style>
#           html {
#             width: 100%;
#             height: 100%;
#           }
#           body {
#             width: 90%;
#             height: 100%;
#             margin: auto;
#           }
#         </style>
#     </head>
#     <body>
#
#         <div class="bk-root">
#             <div class="bk-plotdiv" id="d9575279-7415-4dfb-b7dc-e9c0abaf3174"></div>
#         </div>
#
#         <script type="text/javascript">
#             (function() {
#           var fn = function() {
#             Bokeh.safely(function() {
# ...

# %%
HTML(filename=f'{datapath}/pandexo/V1298TauB_NIRSPECM_1000K.html')
# Out:
# <!DOCTYPE html>
# <html lang="en">
#     <head>
#         <meta charset="utf-8">
#         <title>Bokeh Plot</title>
#
# <link rel="stylesheet" href="https://cdn.pydata.org/bokeh/release/bokeh-0.12.6.min.css" type="text/css" />
#
# <script type="text/javascript" src="https://cdn.pydata.org/bokeh/release/bokeh-0.12.6.min.js"></script>
# <script type="text/javascript">
#     Bokeh.set_log_level("info");
# </script>
#         <style>
#           html {
#             width: 100%;
#             height: 100%;
#           }
#           body {
#             width: 90%;
#             height: 100%;
#             margin: auto;
#           }
#         </style>
#     </head>
#     <body>
#
#         <div class="bk-root">
#             <div class="bk-plotdiv" id="696d47c1-76d7-4468-ade6-6d69edacb9a9"></div>
#         </div>
#
#         <script type="text/javascript">
#             (function() {
#           var fn = function() {
#             Bokeh.safely(function() {
# ...

# %%
HTML(filename=f'{datapath}/pandexo/V1298TauB_NIRSPECM_1250K.html')
# Out:
# <!DOCTYPE html>
# <html lang="en">
#     <head>
#         <meta charset="utf-8">
#         <title>Bokeh Plot</title>
#
# <link rel="stylesheet" href="https://cdn.pydata.org/bokeh/release/bokeh-0.12.6.min.css" type="text/css" />
#
# <script type="text/javascript" src="https://cdn.pydata.org/bokeh/release/bokeh-0.12.6.min.js"></script>
# <script type="text/javascript">
#     Bokeh.set_log_level("info");
# </script>
#         <style>
#           html {
#             width: 100%;
#             height: 100%;
#           }
#           body {
#             width: 90%;
#             height: 100%;
#             margin: auto;
#           }
#         </style>
#     </head>
#     <body>
#
#         <div class="bk-root">
#             <div class="bk-plotdiv" id="dc3b65b3-135d-45da-a08c-deb6aca71d0e"></div>
#         </div>
#
#         <script type="text/javascript">
#             (function() {
#           var fn = function() {
#             Bokeh.safely(function() {
# ...
